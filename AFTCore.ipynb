# %%
import numpy as np

# %%
s = """static const PCA_POINT Frontal_MIDDLE_PCA_POINT[] = {
         {2791, {-37.3342526528987970f,  19.3098761097109350f, -10.4752325848268340f}, Frontal_MIDDLE_evectors + 0},
         {3273, {-24.4794828978287850f,  20.2775648954617860f,  -5.8791049052353825f}, Frontal_MIDDLE_evectors + 48},
         {3308, {-13.4600909955903420f,  16.3121268581479870f,  -5.2476315165555896f}, Frontal_MIDDLE_evectors + 96},
         {5264, {-50.0558352227918420f,  12.5271765039087470f, -19.8763965278613310f}, Frontal_MIDDLE_evectors + 144},
         {962, { 38.3324525053435110f,  19.3435940895305090f, -10.7407217678907130f}, Frontal_MIDDLE_evectors + 192},
         {4746, { 50.4076801205811550f,  12.4513948426682290f, -19.8861466660668780f}, Frontal_MIDDLE_evectors + 240},
         {1491, { 24.1590320508100800f,  20.2853678739868640f,  -5.6764737013554658f}, Frontal_MIDDLE_evectors + 288},
         {1531, { 13.9241694211281040f,  16.3599172099044740f,  -5.1002248860752992f}, Frontal_MIDDLE_evectors + 336},
         {2801, {-37.8235211425150840f,   3.6689433161900942f, -13.8595418402314490f}, Frontal_MIDDLE_evectors + 384},
         {4479, {-37.5380532104213320f,  -3.0461826831433085f, -14.8963691896727500f}, Frontal_MIDDLE_evectors + 432},
         {4581, {-42.2210388985809930f,   0.0128545045058240f, -18.9869829531774880f}, Frontal_MIDDLE_evectors + 480},
         {5281, {-24.2380522717587680f,   4.0638920899999977f, -12.7299559775031130f}, Frontal_MIDDLE_evectors + 528},
         {520, {-18.0044616183515130f,  -0.5481063716188593f, -15.4090640264039250f}, Frontal_MIDDLE_evectors + 576},
         {5274, {-31.5372596467801640f,   4.9977426462502628f, -12.0029829984280280f}, Frontal_MIDDLE_evectors + 624},
         {2871, {-33.4802792610190070f,  -3.8850317617155854f, -13.4068988193720710f}, Frontal_MIDDLE_evectors + 672},
         {2872, {-28.3597599734058220f,  -3.7980899147265186f, -12.5572036772198730f}, Frontal_MIDDLE_evectors + 720},
         {4352, { 37.4706670502093360f,  -3.0873197070813845f, -14.7750734305528690f}, Frontal_MIDDLE_evectors + 768},
         {4755, { 24.0593777878587680f,   3.8592854832423935f, -12.7128536862792530f}, Frontal_MIDDLE_evectors + 816},
         {980, { 31.5133607360672130f,   5.0328320522136218f, -12.0579846423131210f}, Frontal_MIDDLE_evectors + 864},
         {325, { 42.0015122293680250f,  -0.0114936460065205f, -18.6696837547236820f}, Frontal_MIDDLE_evectors + 912},
         {1047, { 28.2895914629342680f,  -3.7726463488911359f, -12.4991896762823980f}, Frontal_MIDDLE_evectors + 960},
         {4409, { 16.4469807712440850f,  -0.9873075965807667f, -14.7802926745332530f}, Frontal_MIDDLE_evectors + 1008},
         {1050, { 33.3203824649582570f,  -3.8515818786542559f, -13.3289419975304280f}, Frontal_MIDDLE_evectors + 1056},
         {973, { 37.6934405580394340f,   3.5668204437422628f, -13.6967143746465720f}, Frontal_MIDDLE_evectors + 1104},
         {4879, {  0.1246392185593285f, -33.6920904187828190f,  22.7049575528243180f}, Frontal_MIDDLE_evectors + 1152},
         {1423, {  0.0609023796152987f, -27.4676526194097690f,  22.1416450522491460f}, Frontal_MIDDLE_evectors + 1200},
         {1852, {  0.0456294479171456f, -19.5666573516241050f,  16.7279572583527880f}, Frontal_MIDDLE_evectors + 1248},
         {4669, {  0.1592268397488683f, -11.6145080109054760f,  10.0695388461442420f}, Frontal_MIDDLE_evectors + 1296},
         {1431, {  0.0000000000000000f,   0.0000000000000000f,   0.0000000000000000f}, Frontal_MIDDLE_evectors + 1344},
         {4705, {  0.0610122262886125f, -43.6121730340553740f,   8.2011158414518022f}, Frontal_MIDDLE_evectors + 1392},
         {3652, {-12.2811503489955760f, -32.1288863079343660f,  12.1059367408522580f}, Frontal_MIDDLE_evectors + 1440},
         {1877, { 12.4318272919628840f, -32.2080556450690660f,  12.3480308410042030f}, Frontal_MIDDLE_evectors + 1488},
         {660, {-18.2889460598942150f, -36.1078611701421580f,  -0.9178397061819258f}, Frontal_MIDDLE_evectors + 1536},
         {4458, {  8.9250598921085889f, -41.3151186629659360f,   3.9358865856717871f}, Frontal_MIDDLE_evectors + 1584},
         {4597, { -8.7469595293311322f, -41.2518735785736580f,   3.8460748867009871f}, Frontal_MIDDLE_evectors + 1632},
         {309, { 18.6134801477990310f, -36.2358466400586180f,  -0.9868062215078208f}, Frontal_MIDDLE_evectors + 1680},
         {1120, { 24.6348271782113210f, -67.4212745953375930f,  -7.9680868546046320f}, Frontal_MIDDLE_evectors + 1728},
         {1155, {  8.3297666091020286f, -56.8468289675364890f,   8.6341725513753982f}, Frontal_MIDDLE_evectors + 1776},
         {2988, { -8.2289423458954101f, -77.8103630171331990f,   5.1057544644951243f}, Frontal_MIDDLE_evectors + 1824},
         {1453, {  0.0893852900326039f, -57.4364514555955670f,  10.0025878786374510f}, Frontal_MIDDLE_evectors + 1872},
         {2479, { 18.4769989998408380f, -61.0319430968977270f,   1.9854109214792524f}, Frontal_MIDDLE_evectors + 1920},
         {50, { 20.2538728074212810f, -72.8156400374656130f,  -3.7750025704487493f}, Frontal_MIDDLE_evectors + 1968},
         {2966, { -8.1278283286874817f, -56.8199742145104590f,   8.6080103398325321f}, Frontal_MIDDLE_evectors + 2016},
         {397, {-19.9296990446996140f, -72.8259067312952770f,  -3.6887416658623304f}, Frontal_MIDDLE_evectors + 2064},
         {5627, {-24.4135466082649160f, -67.4871893909839290f,  -7.9438651463163330f}, Frontal_MIDDLE_evectors + 2112},
         {4252, {-18.2178925342611110f, -61.1067743627980490f,   1.9077466406489432f}, Frontal_MIDDLE_evectors + 2160},
         {1182, {  8.9158710111369004f, -77.8158407805017020f,   4.9991862060868044f}, Frontal_MIDDLE_evectors + 2208},
         {1183, {  0.2351487646765861f, -78.8558268897249090f,   6.3849990426803300f}, Frontal_MIDDLE_evectors + 2256},
         {1443, {  0.1048071481066910f, -63.5635759306287370f,   6.2242219034545778f}, Frontal_MIDDLE_evectors + 2304},
         {4309, { -6.9606869432673646f, -63.6538513452271740f,   4.9586536732668023f}, Frontal_MIDDLE_evectors + 2352},
         {1158, {  0.1090101634932168f, -71.3576506689489920f,   5.6696647676352701f}, Frontal_MIDDLE_evectors + 2400},
         {2972, {-10.0565274591895460f, -70.7715812997616210f,   2.8067477785947705f}, Frontal_MIDDLE_evectors + 2448},
         {2539, {  7.2802695166978149f, -63.6598493367764820f,   4.8998559092180454f}, Frontal_MIDDLE_evectors + 2496},
         {1164, { 10.3476733708584930f, -70.7382589253223700f,   2.8076231912677803f}, Frontal_MIDDLE_evectors + 2544},
         {2632, {-64.7154885814981070f, -20.9211098738174500f, -41.5703791405910860f}, Frontal_MIDDLE_evectors + 2592},
         {3472, {-51.0546217688570610f, -81.9121157828764550f, -36.1320787684436130f}, Frontal_MIDDLE_evectors + 2640},
         {5468, {-64.1342268002929220f, -34.9670226886817020f, -44.2861326056392600f}, Frontal_MIDDLE_evectors + 2688},
         {3534, {-57.4017820805601320f, -68.9312535091625450f, -42.5283439871303910f}, Frontal_MIDDLE_evectors + 2736},
         {3542, {-61.6510621103668650f, -51.4930260654056300f, -46.6871464976462320f}, Frontal_MIDDLE_evectors + 2784},
         {3670, {-41.9506105759163290f, -94.3387792750050240f, -31.1279065422870320f}, Frontal_MIDDLE_evectors + 2832},
         {3815, {-27.6766130304002050f, -99.6365746172843100f, -14.4038975259356000f}, Frontal_MIDDLE_evectors + 2880},
         {1712, {  0.2020053296667762f, -107.3757505938070600f,  -0.8803400017974115f}, Frontal_MIDDLE_evectors + 2928},
         {2035, { 27.7918419155659850f, -99.5924639333685210f, -14.0383669990958850f}, Frontal_MIDDLE_evectors + 2976},
         {1894, { 42.1540282457970150f, -94.3823034709506600f, -31.0275847091825310f}, Frontal_MIDDLE_evectors + 3024},
         {4968, { 64.4130326748080790f, -34.9049134890828580f, -44.2215987560490480f}, Frontal_MIDDLE_evectors + 3072},
         {1762, { 57.5512155204926050f, -69.0115759497346200f, -42.4471064687297140f}, Frontal_MIDDLE_evectors + 3120},
         {795, { 64.9522070341439390f, -20.9023911910231170f, -41.5035350666180490f}, Frontal_MIDDLE_evectors + 3168},
         {1691, { 51.1244115577963070f, -82.0734226894065700f, -35.9366928803423780f}, Frontal_MIDDLE_evectors + 3216},
         {1766, { 61.8779235052766620f, -51.4871293154014540f, -46.6521637816157830f}, Frontal_MIDDLE_evectors + 3264},
};         /**< Set of 3D points defining the deformable 3D model.*/
"""

# %%
# load the 3d values
points_3d_s = s.split("\n")
points_float = []
for line in points_3d_s[1:-2]:
    string_values = line.split(", {")[1].split("}, ")[0].replace("f"," ").split(",")
    string_values = [float(x) for x in string_values]
    points_float.append(string_values)
points_3d = np.array(points_float).T
print points_3d.shape

from matplotlib import pyplot as plt
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = [5, 5]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')


xs = points_3d[0,:]
ys = points_3d[1,:]
zs = points_3d[2,:]
ax.scatter(xs,ys,zs,  c='r')

plt.show()
# Out:
# (3L, 69L)
# <img src="data:image/png;base64,..." width="500">

# %%
from math import cos, sin

def project(average_model, R, t, s):
    return (R * s).dot(points_3d) + t 

def RotY(deg):
    return np.array([[cos(deg),  0, sin(deg)],
                     [    0   ,  1,   0    ],
                     [-sin(deg), 0, cos(deg)]])

# %%
R = np.eye(3)
t = np.zeros((3,1))
s = np.array([[1]])
projected_points = project(points_3d,R,t, s) 
print "no projective transformation, thus no need for K"

from matplotlib import pyplot as plt
# %matplotlib notebook
plt.clf()
plt.scatter(projected_points[0,:], projected_points[1,:])
plt.show()
# Out:
# no projective transformation, thus no need for K
# <img src="data:image/png;base64,..." width="500">

# %%
R_ =  RotY(-0.35)
t = np.zeros((3,1))
s = np.array([[1]])
measured_points = project(points_3d,R_,t, s) 
# %matplotlib notebook
plt.clf()
plt.scatter(measured_points[0,:], measured_points[1,:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# \begin{align}
# f = R * s * v + t \\
# R = 3x3 \\
# s = I * s -> 3x3 \\
# v = 3x69 \\
# t = 3x69 \\
# \end{align}
#
# If considering a single vector
#
# \begin{align}
# f = R * s * v + t \\
# R = 3x3 \\
# s = I * s -> 3x3 \\
# v = 3x1 \\
# t = 3x1 \\
# \end{align}
#
# We want not to find the derivatives with respect to R s and t
# \begin{align}
# \frac{\partial f}{\partial R} ;
# \frac{\partial f}{\partial s} ;
# \frac{\partial f}{\partial t}
# \end{align}
#
# If we analyse separately each output we get the following:
# Note s here is a scalar
# Note f here is a scalar
# \begin{align}
# f_x = R_1^T * s * v + t_x \\
# f_y = R_2^T * s * v + t_y \\
# f_z = R_3^T * s * v + t_z
# \end{align}
#
# If we expand the vector dot product we get for example for x:
#
# Note, \begin{align}v_{i}\end{align} is an element from the vector v while \begin{align}R_1^T\end{align} is a row from R and \begin{align}r_{ii}\end{align} is an element from R
#
# \begin{align}
# f_x = \sum_{i}^3 r_{1i} * s * v_i \\
# \frac{\partial f_x}{\partial r_{11}} = s * v_1 \\
# \frac{\partial f_x}{\partial r_{12}} = s * v_2 \\
# \frac{\partial f_x}{\partial r_{13}} = s * v_3
# \end{align}
#
#
#
# Consequently we analyse each derivative separately.
# Note s here is a scalar, v is a vector
# \begin{align}
# \frac{\partial f_x}{\partial R_1^T} = s * v \\
# \frac{\partial f_y}{\partial R_2^T} = s * v \\
# \frac{\partial f_z}{\partial R_3^T} = s * v
# \end{align}
#
# Thus
# \begin{align}
# \frac{\partial f}{\partial R} = s * m1 * v_T
# \end{align}
# Where m1 is is a column vector of ones
#
# By the same logic we have
#
# \begin{align}
# \frac{\partial f}{\partial t} = 1 \\
# \frac{\partial f}{\partial s} = sum(R * v)
# \end{align}
# Note: 1 here is a vector of ones
#
# The final J
# \begin{bmatrix}
#     \frac{\partial f_{x1}}{\partial r_{11}} & \frac{\partial f_{x1}}{\partial r_{12}} & \frac{\partial f_{x1}}{\partial r_{13}} & \frac{\partial f_{x1}}{\partial r_{21}} & \frac{\partial f_{x1}}{\partial r_{22}} & \frac{\partial f_{x1}}{\partial r_{23}} & \frac{\partial f_{x1}}{\partial r_{31}} & \frac{\partial f_{x1}}{\partial r_{32}} & \frac{\partial f_{x1}}{\partial r_{33}} & \frac{\partial f_{x1}}{\partial t_{x}} & \frac{\partial f_{x1}}{\partial t_{y}} & \frac{\partial f_{x1}}{\partial t_{z}} & \frac{\partial f_{x1}}{\partial s_{x}} \\
#     \frac{\partial f_{y1}}{\partial r_{11}} & \frac{\partial f_{y1}}{\partial r_{12}} & \frac{\partial f_{y1}}{\partial r_{13}} & \frac{\partial f_{y1}}{\partial r_{21}} & \frac{\partial f_{y1}}{\partial r_{22}} & \frac{\partial f_{y1}}{\partial r_{23}} & \frac{\partial f_{y1}}{\partial r_{31}} & \frac{\partial f_{y1}}{\partial r_{32}} & \frac{\partial f_{y1}}{\partial r_{33}} & \frac{\partial f_{y1}}{\partial t_{x}} & \frac{\partial f_{y1}}{\partial t_{y}} & \frac{\partial f_{y1}}{\partial t_{z}} & \frac{\partial f_{y1}}{\partial s_{x}} \\
#     \frac{\partial f_{z1}}{\partial r_{11}} & \frac{\partial f_{z1}}{\partial r_{12}} & \frac{\partial f_{z1}}{\partial r_{13}} & \frac{\partial f_{z1}}{\partial r_{21}} & \frac{\partial f_{z1}}{\partial r_{22}} & \frac{\partial f_{z1}}{\partial r_{23}} & \frac{\partial f_{z1}}{\partial r_{31}} & \frac{\partial f_{z1}}{\partial r_{32}} & \frac{\partial f_{z1}}{\partial r_{33}} & \frac{\partial f_{z1}}{\partial t_{x}} & \frac{\partial f_{z1}}{\partial t_{y}} & \frac{\partial f_{z1}}{\partial t_{z}} & \frac{\partial f_{z1}}{\partial s_{x}} \\
#     \frac{\partial f_{x2}}{\partial r_{11}} & \frac{\partial f_{x2}}{\partial r_{12}} & \frac{\partial f_{x2}}{\partial r_{13}} & \frac{\partial f_{x2}}{\partial r_{21}} & \frac{\partial f_{x2}}{\partial r_{22}} & \frac{\partial f_{x2}}{\partial r_{23}} & \frac{\partial f_{x2}}{\partial r_{31}} & \frac{\partial f_{x2}}{\partial r_{32}} & \frac{\partial f_{x2}}{\partial r_{33}} & \frac{\partial f_{x2}}{\partial t_{x}} & \frac{\partial f_{x2}}{\partial t_{y}} & \frac{\partial f_{x2}}{\partial t_{z}} & \frac{\partial f_{x2}}{\partial s_{x}} \\
#     \frac{\partial f_{y2}}{\partial r_{11}} & \frac{\partial f_{y2}}{\partial r_{12}} & \frac{\partial f_{y2}}{\partial r_{13}} & \frac{\partial f_{y2}}{\partial r_{21}} & \frac{\partial f_{y2}}{\partial r_{22}} & \frac{\partial f_{y2}}{\partial r_{23}} & \frac{\partial f_{y2}}{\partial r_{31}} & \frac{\partial f_{y2}}{\partial r_{32}} & \frac{\partial f_{y2}}{\partial r_{33}} & \frac{\partial f_{y2}}{\partial t_{x}} & \frac{\partial f_{y2}}{\partial t_{y}} & \frac{\partial f_{y2}}{\partial t_{z}} & \frac{\partial f_{y2}}{\partial s_{x}} \\
#     \frac{\partial f_{z2}}{\partial r_{11}} & \frac{\partial f_{z2}}{\partial r_{12}} & \frac{\partial f_{z2}}{\partial r_{13}} & \frac{\partial f_{z2}}{\partial r_{21}} & \frac{\partial f_{z2}}{\partial r_{22}} & \frac{\partial f_{z2}}{\partial r_{23}} & \frac{\partial f_{z2}}{\partial r_{31}} & \frac{\partial f_{z2}}{\partial r_{32}} & \frac{\partial f_{z2}}{\partial r_{33}} & \frac{\partial f_{z2}}{\partial t_{x}} & \frac{\partial f_{z2}}{\partial t_{y}} & \frac{\partial f_{z2}}{\partial t_{z}} & \frac{\partial f_{z2}}{\partial s_{x}} \\
#     \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots & \vdots \\
#     \frac{\partial f_{xn}}{\partial r_{11}} & \frac{\partial f_{xn}}{\partial r_{12}} & \frac{\partial f_{xn}}{\partial r_{13}} & \frac{\partial f_{xn}}{\partial r_{21}} & \frac{\partial f_{xn}}{\partial r_{22}} & \frac{\partial f_{xn}}{\partial r_{23}} & \frac{\partial f_{xn}}{\partial r_{31}} & \frac{\partial f_{xn}}{\partial r_{32}} & \frac{\partial f_{xn}}{\partial r_{33}} & \frac{\partial f_{xn}}{\partial t_{x}} & \frac{\partial f_{xn}}{\partial t_{y}} & \frac{\partial f_{xn}}{\partial t_{z}} & \frac{\partial f_{xn}}{\partial s_{x}} \\
#     \frac{\partial f_{yn}}{\partial r_{11}} & \frac{\partial f_{yn}}{\partial r_{12}} & \frac{\partial f_{yn}}{\partial r_{13}} & \frac{\partial f_{yn}}{\partial r_{21}} & \frac{\partial f_{yn}}{\partial r_{22}} & \frac{\partial f_{yn}}{\partial r_{23}} & \frac{\partial f_{yn}}{\partial r_{31}} & \frac{\partial f_{yn}}{\partial r_{32}} & \frac{\partial f_{yn}}{\partial r_{33}} & \frac{\partial f_{yn}}{\partial t_{x}} & \frac{\partial f_{yn}}{\partial t_{y}} & \frac{\partial f_{yn}}{\partial t_{z}} & \frac{\partial f_{yn}}{\partial s_{x}} \\
#     \frac{\partial f_{zn}}{\partial r_{11}} & \frac{\partial f_{zn}}{\partial r_{12}} & \frac{\partial f_{zn}}{\partial r_{13}} & \frac{\partial f_{zn}}{\partial r_{21}} & \frac{\partial f_{zn}}{\partial r_{22}} & \frac{\partial f_{zn}}{\partial r_{23}} & \frac{\partial f_{zn}}{\partial r_{31}} & \frac{\partial f_{zn}}{\partial r_{32}} & \frac{\partial f_{zn}}{\partial r_{33}} & \frac{\partial f_{zn}}{\partial t_{x}} & \frac{\partial f_{zn}}{\partial t_{y}} & \frac{\partial f_{zn}}{\partial t_{z}} & \frac{\partial f_{zn}}{\partial s_{x}}
# \end{bmatrix}
#
# If we simplyfy because of zeros:
#
# \begin{bmatrix}
# \frac{\partial f_{x1}}{\partial r_{11}} & \frac{\partial f_{x1}}{\partial r_{12}} & \frac{\partial f_{x1}}{\partial r_{13}} & 0 & 0 & 0 & 0 & 0 & 0 & \frac{\partial f_{x1}}{\partial t_{x}} & 0 & 0 & \frac{\partial f_{x1}}{\partial s_{x}} \\
# 0 & 0 & 0 & \frac{\partial f_{y1}}{\partial r_{21}} & \frac{\partial f_{y1}}{\partial r_{22}} & \frac{\partial f_{y1}}{\partial r_{23}} & 0 & 0 & 0 & 0 & \frac{\partial f_{y1}}{\partial t_{y}} & 0 & \frac{\partial f_{y1}}{\partial s_{x}} \\
# 0 & 0 & 0 & 0 & 0 & 0 & \frac{\partial f_{z1}}{\partial r_{31}} & \frac{\partial f_{z1}}{\partial r_{32}} & \frac{\partial f_{z1}}{\partial r_{33}} & 0 & 0 & \frac{\partial f_{z1}}{\partial t_{z}} & \frac{\partial f_{z1}}{\partial s_{x}} \\
# \frac{\partial f_{x2}}{\partial r_{11}} & \frac{\partial f_{x2}}{\partial r_{12}} & \frac{\partial f_{x2}}{\partial r_{13}} & 0 & 0 & 0 & 0 & 0 & 0 & \frac{\partial f_{x2}}{\partial t_{x}} & 0 & 0 & \frac{\partial f_{x2}}{\partial s_{x}} \\
# 0 & 0 & 0 & \frac{\partial f_{y2}}{\partial r_{21}} & \frac{\partial f_{y2}}{\partial r_{22}} & \frac{\partial f_{y2}}{\partial r_{23}} & 0 & 0 & 0 & 0 & \frac{\partial f_{y2}}{\partial t_{y}} & 0 & \frac{\partial f_{y2}}{\partial s_{x}} \\
# 0 & 0 & 0 & 0 & 0 & 0 & \frac{\partial f_{z2}}{\partial r_{31}} & \frac{\partial f_{z2}}{\partial r_{32}} & \frac{\partial f_{z2}}{\partial r_{33}} & 0 & 0 & \frac{\partial f_{z2}}{\partial t_{z}} & \frac{\partial f_{z2}}{\partial s_{x}} \\
# \frac{\partial f_{xn}}{\partial r_{11}} & \frac{\partial f_{xn}}{\partial r_{12}} & \frac{\partial f_{xn}}{\partial r_{13}} & 0 & 0 & 0 & 0 & 0 & 0 & \frac{\partial f_{xn}}{\partial t_{x}} & 0 & 0 & \frac{\partial f_{xn}}{\partial s_{x}} \\
# 0 & 0 & 0 & \frac{\partial f_{yn}}{\partial r_{21}} & \frac{\partial f_{yn}}{\partial r_{22}} & \frac{\partial f_{yn}}{\partial r_{23}} & 0 & 0 & 0 & 0 & \frac{\partial f_{yn}}{\partial t_{y}} & 0 & \frac{\partial f_{yn}}{\partial s_{x}} \\
# 0 & 0 & 0 & 0 & 0 & 0 & \frac{\partial f_{zn}}{\partial r_{31}} & \frac{\partial f_{zn}}{\partial r_{32}} & \frac{\partial f_{zn}}{\partial r_{33}} & 0 & 0 & \frac{\partial f_{zn}}{\partial t_{z}} & \frac{\partial f_{zn}}{\partial s_{x}} \\
# \end{bmatrix}
#
# TODO: Maybe an easier way is to write this in homogeneous coordinates

# %% [markdown]
# | Method Elements | 2D localisation using beacons       | R, t, s estimation AFT            |
# |-----------------|-------------------------------------|-----------------------------------|
# |   measurements  | distances to known beacon locations |  located feature points using SVM |
# | constant value  | beacon location                     |  average 3D model                 |
# | variable x      | 2d position                         |  R, t, s                          |
# | initial value x | can be random 2d position           |  eye(3), [0,0,0], 1               |
# | function f that transforms the constant value using x in order to get a value close to measurements    |  ![image.png](attachment:image.png) |  f = R * s * v + t                 |
# | J of f               |  ![J_df_dx.PNG](J_df_dx.PNG)   |  matrix above                     |
# | compute dx           |  ![dx.PNG](dx.PNG)             |  same                             |
# | update  x            |  ![update_x.PNG](update_x.PNG) |  same                             |
# | retrieve variables from x |    vector size 2x1        |  vector size 13x1                 |
#
# #############################################################################################
# #############################################################################################
# #############################################################################################
# #############################################################################################
# #############################################################################################
#
# Optical flow: Coursera Optical Flow: 2D Point Correspondences minute 6:14 same type of problem
#
# Same video, minute 10:32 is the same formula as
# ![dx.PNG](dx.PNG)
#
# #############################################################################################
# #############################################################################################
# #############################################################################################
# #############################################################################################
# #############################################################################################

# %%
def computeJ(v, R0, s0, t0):
    if v.shape[0] != 3:
        raise ValueError("v should have shape 3xN")
    n_points = v.shape[1]
    
    #unreferenced parameter t0
    
    m1 = np.array([[1],[1],[1]])
    
    # i consider all of them matrices
    J = np.zeros((3*n_points, 9 + 3 + 1)) #9 from rotation, 3 from translation, 1 from scale
    for i in range(n_points):
        v_i = v[:,[i]]
        dR = s0 * (m1.dot(v_i.T))          # shape 3x3 
        ds = np.sum(R.dot(v_i))             # shape 1x1  R.dot(v_i) is shape 3x1
        ds = np.ones((3,1)) * ds
        J[3*i+0, 0:3]  = dR.flatten()[0:3]
        J[3*i+1, 3:6]  = dR.flatten()[3:6]
        J[3*i+2, 6:9]  = dR.flatten()[6:9]
        
        J[3*i+0, 9:12] = np.array([1, 0 ,0])
        J[3*i+1, 9:12] = np.array([0, 1 ,0])
        J[3*i+2, 9:12] = np.array([0, 0 ,1])
        
        J[3*i:3*i+3, 12:13] = np.ones((3,1)) * ds
    return J

v = measured_points
R0 = np.eye(3)
s0 = np.array([[1]])
t0 = np.zeros((3,1))
J = computeJ(v, R0, s0, t0)
print J
# Out:
# [[-3.14788439e+01  1.93098761e+01 -2.26419810e+01 ...  0.00000000e+00
#    0.00000000e+00 -3.48109488e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  1.00000000e+00
#    0.00000000e+00 -3.48109488e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    1.00000000e+00 -3.48109488e+01]
#  ...
#  [ 7.41233575e+01 -5.14871293e+01 -2.26059654e+01 ...  0.00000000e+00
#    0.00000000e+00  3.02628750e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  1.00000000e+00
#    0.00000000e+00  3.02628750e-02]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 ...  0.00000000e+00
#    1.00000000e+00  3.02628750e-02]]

# %%
def computeDX(J,b, fx):
    dx = (J.T.dot(J))
    dx = np.linalg.inv(dx)
    dx = dx.dot(J.T)
    difference = b -fx
    ################################
    ################################
    ################################
    #maybe difference.T.flatted
    difference = difference.T
    dx = dx.dot(difference.flatten())
    return dx

b = measured_points
fx = project(points_3d, R0, t0, s0)
dx = computeDX(J, b, fx)
print dx
# Out:
# [ 3.05563964e-02 -1.00459812e-02 -3.55579828e-01 -1.27550241e-02
#  -1.65864552e-02 -1.17215558e-02  3.24119058e-01 -9.30721759e-03
#   5.29603067e-02  1.11022302e-16 -9.85012524e-16 -1.30451205e-15
#   1.10978451e-02]

# %%
def optimise(points_3d, measured_points, alpha = 1.0):
    R0 = np.eye(3)
    s0 = np.array([[1]])
    t0 = np.zeros((3,1))
    v = measured_points.copy()
    for i in range(10):
        J = computeJ(v, R0, s0, t0)
        fx = project(points_3d, R0, t0, s0)
        dx = computeDX(J, v, fx)
        
        dR = dx[0:9].reshape((3,3))
        dt = dx[9:12].reshape((3,1))
        ds = dx[12:13]
        
        R0 += dR * alpha
        dt += dt * alpha
        ds += ds * alpha
        
    return R0, s0, t0

R_est, s_est, t_est = optimise(points_3d, measured_points, alpha = 0.5)
print R_est
print s_est
print t_est

R_true =  RotY(-0.35)
t_true = np.zeros((3,1))
s_true = np.array([[1]])
print R_true
print s_true
print t_true
# Out:
# [[ 9.39460231e-01  4.47106558e-04 -3.43591500e-01]
#  [-1.62226942e-04  1.00023754e+00  9.45617999e-04]
#  [ 3.44713490e-01  2.34270605e-04  9.39000912e-01]]
# [[1]]
# [[0.]
#  [0.]
#  [0.]]
# [[ 0.93937271  0.         -0.34289781]
#  [ 0.          1.          0.        ]
#  [ 0.34289781  0.          0.93937271]]
# [[1]]
# [[0.]
#  [0.]
#  [0.]]

# %%
measured_points_est = project(points_3d,R_est,t_est, s_est) 
from matplotlib import pyplot as plt
# %matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = [5, 5]
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')


xs = measured_points_est[0,:]
ys = measured_points_est[1,:]
zs = measured_points_est[2,:]
ax.scatter(xs,ys,zs,  c='r')
xs = measured_points[0,:]
ys = measured_points[1,:]
zs = measured_points[2,:]
ax.scatter(xs,ys,zs,  c='b')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
measured_points = project(points_3d,R_true,t_true, s_true) 
measured_points_est = project(points_3d,R_est,t_est, s_est) 
# %matplotlib notebook
plt.clf()
plt.scatter(measured_points[0,:], measured_points[1,:])
plt.scatter(measured_points_est[0,:], measured_points_est[1,:])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="500">
